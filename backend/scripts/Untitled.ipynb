# %%
# !python /home/ec2-user/SageMaker/context_graph_demo/backend/scripts/generate_sample_data.py
# Out:
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/context_graph_demo/backend/scripts/generate_sample_data.py", line 15, in <module>
#     from faker import Faker
# ModuleNotFoundError: No module named 'faker'

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.2 MB/s  0:00:00
# ...
